# %%
import cv2 
import numpy as np
from matplotlib import pyplot as plt

# histogram bize fotoğrafların renk değerlerini verir
img1=cv2.imread(r"C:\Users\korkm\Downloads\14.1 smile.jpg.jpg")
img = np.zeros((500,500),np.uint8)# 500 e 500 bir resim oluşturduk
b,g,r=cv2.split(img1)                                    
#plt.hist(img1.ravel(),256,[0,256])# histogramı çizdiğimiz fonksiyon-- ravel ile matris değerlerini tek bir satıra döktük
plt.hist(b.ravel(),256,[0,256])
plt.hist(g.ravel(),256,[0,256])
plt.hist(r.ravel(),256,[0,256])

plt.show()


cv2.imshow("deneme",img1)

cv2.waitKey(0)
cv2.destroyAllWindows()
